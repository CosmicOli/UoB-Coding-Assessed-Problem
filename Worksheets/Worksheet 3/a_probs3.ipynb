# %% [markdown]
# # Assessed Problems 3
#
# Each two week block has an associated assessed problems sheet. There are always two questions with equal weighting.
#
#
# - **All questions are marked in class by the demonstrators and can be completed in the blank assessed problems submission notebook.** You can have multiple attempts and demonstrators will give you feedback on your approach. You can often solve the problem in multiple ways but you will need to reach a required standard to receive a pass.
#
# **It is expected that you attend all timetabled coding lab sessions assigned to you. This will assist in allowing enough time to speak to a demonstrator to get your attempt for question 1 graded.**
#
# You should also submit working code for each problem via the canvas upload link provided. This will be used as a record of your work, and for plaigiarism and validation checks for question 2.

# %% [markdown]
# ***
# ## Q1) Dice and Coin (2 points)
#
# The data file `dice_rolls.txt` contains data from a random dice simulation. Each row of data is generated by a sequence of two processes.
#
# - An coin is tossed with unknown probabilities $p_{heads}$ and $p_{tails}$.
# - If a tails is seen, a biased red 6-sided dice is thrown.
# - If a heads is seen, a differently-biased blue 6-sided dice is thrown.
# - The dice coin toss result and the outcome of the dice roll are recorded as a row in the data file.
# - This process is repeated 10,000 times.
#
# Column 1 of the data file has `0` for tails and `1` for heads. Column 2 records the value seen of the dice.
#
# - a) Load the data file and write a programme to calculate the probabilities for the coin and each dice.

# %%
import numpy as np;

path = "dice_rolls.txt";
diceRolls = np.loadtxt(path);

tailsLanded = 0;
headsLanded = 0;
redRolls = [];
blueRolls = [];

for coinDicePair in diceRolls:
    if (coinDicePair[0]):
        tailsLanded += 1;
        redRolls.append(coinDicePair[1]);
    else:
        headsLanded += 1;
        blueRolls.append(coinDicePair[1]);

tailsProbability = tailsLanded / (tailsLanded + headsLanded);
headsProbability = 1 - tailsProbability;
print(f"The coin's observed tails probability is {tailsProbability} and observed heads probability is {headsProbability}.");

def CalculateDiceProbabilities(rolls):
    diceProbabilities = np.zeros(6);
    total = 0;

    for roll in rolls:
        diceProbabilities[int(roll - 1)] += 1;
        total += 1;

    diceProbabilities /= total;

    return diceProbabilities;

print(f"The red dice has the observed probabilities {CalculateDiceProbabilities(redRolls)} (1 to 6 respectively).");
print(f"The blue dice has the observed probabilities {CalculateDiceProbabilities(blueRolls)} (1 to 6 respectively).");
# Out:
# The coin's observed tails probability is 0.5998 and observed heads probability is 0.4002.
# The red dice has the observed probabilities [0.23674558 0.14804935 0.07919306 0.14988329 0.19556519 0.19056352] (1 to 6 respectively).
# The blue dice has the observed probabilities [0.15317341 0.14067966 0.1884058  0.17216392 0.16991504 0.17566217] (1 to 6 respectively).

# %% [markdown]
# ***
#
# ## Q2) The semi-empirical mass formula (4 points)
# <!-- newman ex2.10 -->
#
#
#
# In nuclear physics, the semi-empirical mass formula is a formula for calculating the approximate nuclear binding energy $B$ of an atomic nucleus with atomic number $Z$ and mass number $A$ :
#
# $$
# B=a_1 A-a_2 A^{2 / 3}-a_3 \frac{Z^2}{A^{1 / 3}}-a_4 \frac{(A-2 Z)^2}{A}+\frac{a_5}{A^{1 / 2}},
# $$
#
# where, in units of millions of electron volts, the constants are $a_1=15.8, a_2=18.3$, $a_3=0.714, a_4=23.2$, and
#
# $$
# a_5= \begin{cases}0 & \text { if } A \text { is odd, } \\ 12.0 & \text { if } A \text { and } Z \text { are both even, } \\ -12.0 & \text { if } A \text { is even and } Z \text { is odd. }\end{cases}
# $$
#
# a) Write a program that takes as its input the values of $A$ and $Z$, and prints out the binding energy for the corresponding atom. Use your program to find the binding energy of an atom with $A=58$ and $Z=28$. (Hint: The correct answer is around $500 \mathrm{MeV}$.)
#
# b) Modify your program to print out not the total binding energy $B$, but the binding energy per nucleon, which is $B / A$.
#
# c) Now modify your program so that it takes as input just a single value of the atomic number $Z$ and then goes through all values of $A$ from $A=Z$ to $A=3 Z$, to find the one that has the largest binding energy per nucleon. This is the most stable nucleus with the given atomic number. Have your program print out the value of $A$ for this most stable nucleus and the value of the binding energy per nucleon.
#
# d) Modify your program again so that, instead of taking $\mathrm{Z}$ as input, it runs through all values of $Z$ from 1 to 100 and prints out the most stable value of $A$ for each one. At what value of $Z$ does the maximum binding energy per nucleon occur? (The true answer, in real life, is $Z=28$, which is nickel.)

# %%
# Part a
validatingInputs = True;
while (validatingInputs):
    try:
        print("Please enter a value for A:");
        A = int(input());

        print("Please enter a value for Z:");
        Z = int(input());

        validatingInputs = False;
    except:
        print("Please try again, making sure to enter integers.");

a1 = 15.8;
a2 = 18.3;
a3 = 0.714;
a4 = 23.2;
a5 = ((A + 1) % 2) * ((-1) ** (Z % 2)) * 12;
B = a1 * A - a2 * (A ** (2/3)) - a3 * ((Z ** 2) / (A ** (1/3))) - a4 * (((A - 2 * Z) ** 2) / A) + a5 / (A ** (1 / 2));

print (f"Your total binding energy, B, is {B}.");

print (f"Your binding energy per nucleon is {B / A}.")
# Out:
# Please enter a value for A:
# Please enter a value for Z:
# Your total binding energy, B, is 497.5620206224374.
# Your binding energy per nucleon is 8.578655527973059.

# %%
# Part b
validatingInputs = True;
while (validatingInputs):
    try:
        print("Please enter a value for A:");
        A = int(input());

        print("Please enter a value for Z:");
        Z = int(input());

        validatingInputs = False;
    except:
        print("Please try again, making sure to enter integers.");

a1 = 15.8;
a2 = 18.3;
a3 = 0.714;
a4 = 23.2;
a5 = ((A + 1) % 2) * ((-1) ** (Z % 2)) * 12;
B = a1 * A - a2 * (A ** (2/3)) - a3 * ((Z ** 2) / (A ** (1/3))) - a4 * (((A - 2 * Z) ** 2) / A) + a5 / (A ** (1 / 2));

print (f"Your binding energy per nucleon is {B / A}.")
# Out:
# Please enter a value for A:
# Please enter a value for Z:
# Your binding energy per nucleon is 8.578655527973059.

# %%
# Part c
validatingInputs = True;
while (validatingInputs):
    try:
        print("Please enter a value for Z:");
        Z = int(input());

        validatingInputs = False;
    except:
        print("Please try again, making sure to enter integers.");

a1 = 15.8;
a2 = 18.3;
a3 = 0.714;
a4 = 23.2;

bindingEnergiesPerNucleon = [];
for A in range(Z, 3 * Z + 1):
    a5 = ((A + 1) % 2) * ((-1) ** (Z % 2)) * 12;
    B = a1 * A - a2 * (A ** (2/3)) - a3 * ((Z ** 2) / (A ** (1/3))) - a4 * (((A - 2 * Z) ** 2) / A) + a5 / (A ** (1 / 2));
    bindingEnergiesPerNucleon.append(B / A);

maximumBindingEnergyPerNucleon = max(bindingEnergiesPerNucleon);
maximumBindingEnergyPerNucleon_A = bindingEnergiesPerNucleon.index(maximumBindingEnergyPerNucleon) + Z;

print (f"The highest binding energy per nucleon for a value of Z = {Z} is {maximumBindingEnergyPerNucleon} for a value of A = {maximumBindingEnergyPerNucleon_A}.")
# Out:
# Please enter a value for Z:
# The highest binding energy per nucleon for a value of Z = 28 is 8.70245768367189 for a value of A = 62.

# %%
# Part d
maximumBindingEnergyPerNucleonForEachZ = [];

for Z in range(1, 101):
    a1 = 15.8;
    a2 = 18.3;
    a3 = 0.714;
    a4 = 23.2;

    bindingEnergiesPerNucleon = [];
    for A in range(Z, 3 * Z + 1):
        a5 = ((A + 1) % 2) * ((-1) ** (Z % 2)) * 12;
        B = a1 * A - a2 * (A ** (2/3)) - a3 * ((Z ** 2) / (A ** (1/3))) - a4 * (((A - 2 * Z) ** 2) / A) + a5 / (A ** (1 / 2));
        bindingEnergiesPerNucleon.append(B / A);

    maximumBindingEnergyPerNucleon = max(bindingEnergiesPerNucleon);
    maximumBindingEnergyPerNucleon_A = bindingEnergiesPerNucleon.index(maximumBindingEnergyPerNucleon) + Z;

    maximumBindingEnergyPerNucleonForEachZ.append(maximumBindingEnergyPerNucleon);

    print (f"The highest binding energy per nucleon for a value of Z = {Z} is {maximumBindingEnergyPerNucleon} for a value of A = {maximumBindingEnergyPerNucleon_A}.")

maximumBindingEnergyPerNucleonForAllZ = max(maximumBindingEnergyPerNucleonForEachZ);
maximumBindingEnergyPerNucleonForAllZ_Z = maximumBindingEnergyPerNucleonForEachZ.index(maximumBindingEnergyPerNucleonForAllZ) + 1;

print (f"\nThe maximum binding energy per nucleon is {maximumBindingEnergyPerNucleonForAllZ} at a Z = {maximumBindingEnergyPerNucleonForAllZ_Z}.")
# Out:
# The highest binding energy per nucleon for a value of Z = 1 is 0.36869091831015827 for a value of A = 3.
# The highest binding energy per nucleon for a value of Z = 2 is 5.321930578649441 for a value of A = 4.
# The highest binding energy per nucleon for a value of Z = 3 is 5.280168164356119 for a value of A = 7.
# The highest binding energy per nucleon for a value of Z = 4 is 6.466330085889912 for a value of A = 8.
# The highest binding energy per nucleon for a value of Z = 5 is 6.650123444727665 for a value of A = 11.
# The highest binding energy per nucleon for a value of Z = 6 is 7.200918138809924 for a value of A = 14.
# The highest binding energy per nucleon for a value of Z = 7 is 7.330860591990981 for a value of A = 15.
# The highest binding energy per nucleon for a value of Z = 8 is 7.719275577459026 for a value of A = 18.
# The highest binding energy per nucleon for a value of Z = 9 is 7.73697768275634 for a value of A = 19.
# The highest binding energy per nucleon for a value of Z = 10 is 8.035350864715019 for a value of A = 22.
# The highest binding energy per nucleon for a value of Z = 11 is 8.025554739665797 for a value of A = 25.
# The highest binding energy per nucleon for a value of Z = 12 is 8.241172535624845 for a value of A = 26.
# The highest binding energy per nucleon for a value of Z = 13 is 8.240988355754636 for a value of A = 29.
# The highest binding energy per nucleon for a value of Z = 14 is 8.37916169002579 for a value of A = 30.
# The highest binding energy per nucleon for a value of Z = 15 is 8.38521415855582 for a value of A = 33.
# The highest binding energy per nucleon for a value of Z = 16 is 8.489230168218935 for a value of A = 36.
# The highest binding energy per nucleon for a value of Z = 17 is 8.48201495174352 for a value of A = 37.
# The highest binding energy per nucleon for a value of Z = 18 is 8.573405285254953 for a value of A = 40.
# The highest binding energy per nucleon for a value of Z = 19 is 8.551826855569242 for a value of A = 43.
# The highest binding energy per nucleon for a value of Z = 20 is 8.627152167121634 for a value of A = 44.
# The highest binding energy per nucleon for a value of Z = 21 is 8.610130576802973 for a value of A = 47.
# The highest binding energy per nucleon for a value of Z = 22 is 8.6585154571142 for a value of A = 48.
# The highest binding energy per nucleon for a value of Z = 23 is 8.645234048730842 for a value of A = 51.
# The highest binding energy per nucleon for a value of Z = 24 is 8.687306583887372 for a value of A = 54.
# The highest binding energy per nucleon for a value of Z = 25 is 8.662703971015583 for a value of A = 55.
# The highest binding energy per nucleon for a value of Z = 26 is 8.701432576808987 for a value of A = 58.
# The highest binding energy per nucleon for a value of Z = 27 is 8.678053678353882 for a value of A = 61.
# The highest binding energy per nucleon for a value of Z = 28 is 8.70245768367189 for a value of A = 62.
# The highest binding energy per nucleon for a value of Z = 29 is 8.681907349580422 for a value of A = 65.
# The highest binding energy per nucleon for a value of Z = 30 is 8.701580328486784 for a value of A = 68.
# The highest binding energy per nucleon for a value of Z = 31 is 8.675012598311142 for a value of A = 69.
# The highest binding energy per nucleon for a value of Z = 32 is 8.693433639739787 for a value of A = 72.
# The highest binding energy per nucleon for a value of Z = 33 is 8.668156247337208 for a value of A = 75.
# The highest binding energy per nucleon for a value of Z = 34 is 8.67683411103597 for a value of A = 76.
# The highest binding energy per nucleon for a value of Z = 35 is 8.653727479263061 for a value of A = 79.
# The highest binding energy per nucleon for a value of Z = 36 is 8.66141248935323 for a value of A = 82.
# The highest binding energy per nucleon for a value of Z = 37 is 8.633940444065898 for a value of A = 85.
# The highest binding energy per nucleon for a value of Z = 38 is 8.639441275530453 for a value of A = 86.
# The highest binding energy per nucleon for a value of Z = 39 is 8.613815033672552 for a value of A = 89.
# The highest binding energy per nucleon for a value of Z = 40 is 8.614514461544127 for a value of A = 92.
# The highest binding energy per nucleon for a value of Z = 41 is 8.587741675710747 for a value of A = 93.
# The highest binding energy per nucleon for a value of Z = 42 is 8.588337807352417 for a value of A = 96.
# The highest binding energy per nucleon for a value of Z = 43 is 8.561488033970447 for a value of A = 99.
# The highest binding energy per nucleon for a value of Z = 44 is 8.557428804696526 for a value of A = 102.
# The highest binding energy per nucleon for a value of Z = 45 is 8.531857077904819 for a value of A = 103.
# The highest binding energy per nucleon for a value of Z = 46 is 8.52785864674169 for a value of A = 106.
# The highest binding energy per nucleon for a value of Z = 47 is 8.500490244095234 for a value of A = 109.
# The highest binding energy per nucleon for a value of Z = 48 is 8.4940569666179 for a value of A = 110.
# The highest binding energy per nucleon for a value of Z = 49 is 8.46797678166812 for a value of A = 113.
# The highest binding energy per nucleon for a value of Z = 50 is 8.460713172533021 for a value of A = 116.
# The highest binding energy per nucleon for a value of Z = 51 is 8.433224407343122 for a value of A = 119.
# The highest binding energy per nucleon for a value of Z = 52 is 8.424696665334825 for a value of A = 120.
# The highest binding energy per nucleon for a value of Z = 53 is 8.398332486638505 for a value of A = 123.
# The highest binding energy per nucleon for a value of Z = 54 is 8.38868945344295 for a value of A = 126.
# The highest binding energy per nucleon for a value of Z = 55 is 8.361310553455423 for a value of A = 129.
# The highest binding energy per nucleon for a value of Z = 56 is 8.350819725669146 for a value of A = 130.
# The highest binding energy per nucleon for a value of Z = 57 is 8.32443069811602 for a value of A = 133.
# The highest binding energy per nucleon for a value of Z = 58 is 8.313019639868703 for a value of A = 136.
# The highest binding energy per nucleon for a value of Z = 59 is 8.285884693887583 for a value of A = 139.
# The highest binding energy per nucleon for a value of Z = 60 is 8.273583815729522 for a value of A = 140.
# The highest binding energy per nucleon for a value of Z = 61 is 8.247327458286065 for a value of A = 143.
# The highest binding energy per nucleon for a value of Z = 62 is 8.234582872513133 for a value of A = 146.
# The highest binding energy per nucleon for a value of Z = 63 is 8.207769087134613 for a value of A = 149.
# The highest binding energy per nucleon for a value of Z = 64 is 8.193813966434627 for a value of A = 150.
# The highest binding energy per nucleon for a value of Z = 65 is 8.167786207290451 for a value of A = 153.
# The highest binding energy per nucleon for a value of Z = 66 is 8.154024477520512 for a value of A = 156.
# The highest binding energy per nucleon for a value of Z = 67 is 8.127574530301825 for a value of A = 159.
# The highest binding energy per nucleon for a value of Z = 68 is 8.11278037767185 for a value of A = 162.
# The highest binding energy per nucleon for a value of Z = 69 is 8.086373082934724 for a value of A = 163.
# The highest binding energy per nucleon for a value of Z = 70 is 8.071829365612306 for a value of A = 166.
# The highest binding energy per nucleon for a value of Z = 71 is 8.045764583108769 for a value of A = 169.
# The highest binding energy per nucleon for a value of Z = 72 is 8.030368571593026 for a value of A = 172.
# The highest binding energy per nucleon for a value of Z = 73 is 8.004105311543137 for a value of A = 175.
# The highest binding energy per nucleon for a value of Z = 74 is 7.988369073415251 for a value of A = 176.
# The highest binding energy per nucleon for a value of Z = 75 is 7.962697427019249 for a value of A = 179.
# The highest binding energy per nucleon for a value of Z = 76 is 7.946838055684514 for a value of A = 182.
# The highest binding energy per nucleon for a value of Z = 77 is 7.921016888554693 for a value of A = 185.
# The highest binding energy per nucleon for a value of Z = 78 is 7.904575879934101 for a value of A = 188.
# The highest binding energy per nucleon for a value of Z = 79 is 7.87868400232803 for a value of A = 191.
# The highest binding energy per nucleon for a value of Z = 80 is 7.862438691993173 for a value of A = 192.
# The highest binding energy per nucleon for a value of Z = 81 is 7.837047201045294 for a value of A = 195.
# The highest binding energy per nucleon for a value of Z = 82 is 7.82033857608665 for a value of A = 198.
# The highest binding energy per nucleon for a value of Z = 83 is 7.794899333942829 for a value of A = 201.
# The highest binding energy per nucleon for a value of Z = 84 is 7.777785761025879 for a value of A = 204.
# The highest binding energy per nucleon for a value of Z = 85 is 7.75239433360284 for a value of A = 205.
# The highest binding energy per nucleon for a value of Z = 86 is 7.735485475322138 for a value of A = 208.
# The highest binding energy per nucleon for a value of Z = 87 is 7.710478810144077 for a value of A = 211.
# The highest binding energy per nucleon for a value of Z = 88 is 7.693222175964613 for a value of A = 214.
# The highest binding energy per nucleon for a value of Z = 89 is 7.668228396728228 for a value of A = 217.
# The highest binding energy per nucleon for a value of Z = 90 is 7.65068598823387 for a value of A = 220.
# The highest binding energy per nucleon for a value of Z = 91 is 7.625739835440575 for a value of A = 223.
# The highest binding energy per nucleon for a value of Z = 92 is 7.608214013689897 for a value of A = 224.
# The highest binding energy per nucleon for a value of Z = 93 is 7.583639834526779 for a value of A = 227.
# The highest binding energy per nucleon for a value of Z = 94 is 7.566035830526522 for a value of A = 230.
# The highest binding energy per nucleon for a value of Z = 95 is 7.5415108314640555 for a value of A = 233.
# The highest binding energy per nucleon for a value of Z = 96 is 7.523703637516345 for a value of A = 236.
# The highest binding energy per nucleon for a value of Z = 97 is 7.499251800171257 for a value of A = 239.
# The highest binding energy per nucleon for a value of Z = 98 is 7.481279349508352 for a value of A = 242.
# The highest binding energy per nucleon for a value of Z = 99 is 7.456937323389022 for a value of A = 243.
# The highest binding energy per nucleon for a value of Z = 100 is 7.439122944429214 for a value of A = 246.
#
# The maximum binding energy per nucleon is 8.70245768367189 at a Z = 28.
